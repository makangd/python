# %%
Map examples

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
import pandas as pd
cities = pd.read_csv('Data/non-spatial/california_cities.csv')

# Extract the data we're interested in
lat = cities['latd'].values
lon = cities['longd'].values
population = cities['population_total'].values
area = cities['area_total_km2'].values

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution='h', 
            lat_0=37.5, lon_0=-119,
            width=1E6, height=1.2E6)
m.shadedrelief()
m.drawcoastlines(color='gray')
m.drawcountries(color='gray')
m.drawstates(color='gray')

# 2. scatter city data, with color reflecting population
# and size reflecting area
m.scatter(lon, lat, latlon=True,
          c=np.log10(population), s=area,
          cmap='Reds', alpha=0.8)

# 3. create colorbar and legend
plt.colorbar(label=r'$\log_{10}({\rm population})$')
plt.clim(3, 7)

# make legend with dummy points
for a in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.5, s=a,
                label=str(a) + ' km$^2$')
plt.legend(scatterpoints=1, frameon=False,
           labelspacing=1, loc='lower left');

# %%
# Libraries
import pandas as pd
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
 
# Set the dimension of the figure
my_dpi=96
plt.figure(figsize=(2600/my_dpi, 1800/my_dpi), dpi=my_dpi)
 
# read the data (on the web)
data = pd.read_csv('http://python-graph-gallery.com/wp-content/uploads/TweetSurfData.csv', sep=";")
 
# Make the background map
m=Basemap(llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m.fillcontinents(color='grey', alpha=0.3)
m.drawcoastlines(linewidth=0.1, color="white")
 
# prepare a color for each point depending on the continent.
data['labels_enc'] = pd.factorize(data['homecontinent'])[0]
 
# Add a point per position
m.scatter(data['homelon'], data['homelat'], s=data['n']/6, alpha=0.4, c=data['labels_enc'], cmap="Set1")
 
# copyright and source data info
plt.text( -170, -58,'Where people talk about #Surf\n\nData collected on twitter by @R_Graph_Gallery during 300 days\nPlot realized with Python and the Basemap library', ha='left', va='bottom', size=9, color='#555555' )
 
# Save as png
plt.savefig('#315_Tweet_Surf_Bubble_map1.png', bbox_inches='tight')

# %%
from netCDF4 import Dataset
data = Dataset('Data/raster/gistemp250.nc')

from netCDF4 import date2index
from datetime import datetime
timeindex = date2index(datetime(2014, 1, 15),
                       data.variables['time'])

# %%
lat = data.variables['lat'][:]
lon = data.variables['lon'][:]
lon, lat = np.meshgrid(lon, lat)
temp_anomaly = data.variables['tempanomaly'][timeindex]

# %%
fig = plt.figure(figsize=(10, 8))
m = Basemap(projection='lcc', resolution='c',
            width=8E6, height=8E6, 
            lat_0=45, lon_0=-100,)
m.shadedrelief(scale=0.5)
m.pcolormesh(lon, lat, temp_anomaly,
             latlon=True, cmap='RdBu_r')
plt.clim(-8, 8)
m.drawcoastlines(color='lightgray')

plt.title('January 2014 Temperature Anomaly')
plt.colorbar(label='temperature anomaly (°C)');

# %%
world.folium.plot()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
world.folium.chloropeth(color_by= 'pop_est',
          tooltip=['name'],
          color= 'green',
          zoom= 1,
          style = {'color': 'black',
                    'weight': 1,
                    'dashArray': '10, 5',
                    'fillOpacity': 0.5,
                  })
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopandas 
import geopatra 
import random

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))
cities['value'] = [int(random.randint(10, 1000)) for i in range(len(cities))]

# %%
cities.folium.heatmap(style={'min_opacity': 0.3}, zoom=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from IPython.display import IFrame
kmap_3 = world.kepler.plot(name = 'world',
        tooltip=['continent', 'pop_est'],
        stroke_color=[0,0,0],
        stroke_thickness=1,
        color_field = 'pop_est',
        color_scheme = 'Blues',
        color_scheme_steps = 5
)
kmap_3.save_to_html(file_name='kepler_map3.html')

IFrame('kepler_map3.html', width=900, height=500)
# Out:
# User Guide: https://github.com/keplergl/kepler.gl/blob/master/docs/keplergl-jupyter/user-guide.md
# Map saved to kepler_map3.html!
# /home/sth02bh/.local/lib/python3.8/site-packages/geopandas/geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
# /home/sth02bh/.local/lib/python3.8/site-packages/geopandas/geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
#         <iframe
#             width="900"
#             height="500"
#             src="kepler_map3.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# !pip install keplergl
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: keplergl in /home/sth02bh/.local/lib/python3.8/site-packages (0.1.2)
# Requirement already satisfied: pandas>=0.23.0 in /home/sth02bh/.local/lib/python3.8/site-packages (from keplergl) (1.0.3)
# Requirement already satisfied: Shapely>=1.6.4.post2 in /home/sth02bh/.local/lib/python3.8/site-packages (from keplergl) (1.7.0)
# Requirement already satisfied: traittypes>=0.2.1 in /home/sth02bh/.local/lib/python3.8/site-packages (from keplergl) (0.2.1)
# Requirement already satisfied: geopandas>=0.5.0 in /home/sth02bh/.local/lib/python3.8/site-packages (from keplergl) (0.8.1)
# Requirement already satisfied: ipywidgets<8,>=7.0.0 in /home/sth02bh/.local/lib/python3.8/site-packages (from keplergl) (7.5.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.23.0->keplergl) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/sth02bh/.local/lib/python3.8/site-packages (from pandas>=0.23.0->keplergl) (1.18.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/lib/python3/dist-packages (from pandas>=0.23.0->keplergl) (2.7.3)
# Requirement already satisfied: traitlets>=4.2.2 in /home/sth02bh/.local/lib/python3.8/site-packages (from traittypes>=0.2.1->keplergl) (4.3.3)
# Requirement already satisfied: fiona in /home/sth02bh/.local/lib/python3.8/site-packages (from geopandas>=0.5.0->keplergl) (1.8.13.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /home/sth02bh/.local/lib/python3.8/site-packages (from geopandas>=0.5.0->keplergl) (2.6.1.post1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/sth02bh/.local/lib/python3.8/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /home/sth02bh/.local/lib/python3.8/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (7.13.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/sth02bh/.local/lib/python3.8/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.2.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/sth02bh/.local/lib/python3.8/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.0.6)
# Requirement already satisfied: ipython-genutils in /home/sth02bh/.local/lib/python3.8/site-packages (from traitlets>=4.2.2->traittypes>=0.2.1->keplergl) (0.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from traitlets>=4.2.2->traittypes>=0.2.1->keplergl) (1.14.0)
# Requirement already satisfied: decorator in /home/sth02bh/.local/lib/python3.8/site-packages (from traitlets>=4.2.2->traittypes>=0.2.1->keplergl) (4.4.2)
# Requirement already satisfied: attrs>=17 in /usr/lib/python3/dist-packages (from fiona->geopandas>=0.5.0->keplergl) (19.3.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/lib/python3/dist-packages (from fiona->geopandas>=0.5.0->keplergl) (7.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/sth02bh/.local/lib/python3.8/site-packages (from fiona->geopandas>=0.5.0->keplergl) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /home/sth02bh/.local/lib/python3.8/site-packages (from fiona->geopandas>=0.5.0->keplergl) (0.5.0)
# Requirement already satisfied: munch in /home/sth02bh/.local/lib/python3.8/site-packages (from fiona->geopandas>=0.5.0->keplergl) (2.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/sth02bh/.local/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (6.0.3)
# Requirement already satisfied: jedi>=0.10 in /home/sth02bh/.local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (0.15.2)
# Requirement already satisfied: pygments in /usr/lib/python3/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (2.3.1)
# Requirement already satisfied: pickleshare in /home/sth02bh/.local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (0.7.5)
# Requirement already satisfied: backcall in /home/sth02bh/.local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/lib/python3/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (4.6.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (46.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/sth02bh/.local/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (3.0.5)
# Requirement already satisfied: tornado>=4.2 in /home/sth02bh/.local/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (6.0.4)
# Requirement already satisfied: jupyter-client in /home/sth02bh/.local/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (6.1.3)
# Requirement already satisfied: jupyter-core in /home/sth02bh/.local/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/lib/python3/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (3.2.0)
# Requirement already satisfied: Send2Trash in /home/sth02bh/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /home/sth02bh/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (2.10.1)
# Requirement already satisfied: prometheus-client in /home/sth02bh/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.1)
# Requirement already satisfied: pyzmq>=17 in /home/sth02bh/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (19.0.0)
# Requirement already satisfied: nbconvert in /home/sth02bh/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (5.6.1)
# Requirement already satisfied: parso>=0.5.2 in /home/sth02bh/.local/lib/python3.8/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sth02bh/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.0.0->keplergl) (0.1.9)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /home/sth02bh/.local/lib/python3.8/site-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/sth02bh/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.4)
# Requirement already satisfied: defusedxml in /home/sth02bh/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/lib/python3/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.3)
# Requirement already satisfied: bleach in /home/sth02bh/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (3.1.4)
# Requirement already satisfied: testpath in /home/sth02bh/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/sth02bh/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.4.2)
# Requirement already satisfied: webencodings in /home/sth02bh/.local/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.5.1)

# %%
import pandas as pd
df=pd.read_csv('kepler.gl-data/nyctrips/data.csv')
print('Shape=>',df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-ddf719b4f7f9> in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('kepler.gl-data/nyctrips/data.csv')
#       3 print('Shape=>',df.shape)
#       4 df.head()
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File kepler.gl-data/nyctrips/data.csv does not exist: 'kepler.gl-data/nyctrips/data.csv'
